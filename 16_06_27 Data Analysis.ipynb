# %%
import Spectrum_Analysis as SA
import matplotlib.pyplot as plt
import numpy as np
analogHP_DataHome = "C:\\Users\\Mark\\Documents\\My Data Analysis\\Data 16_06_27\\Analog Servo Data\\HP 4395A Data\\"  
analogSRS_DataHome = "C:\\Users\\Mark\\Documents\\My Data Analysis\\Data 16_06_27\\Analog Servo Data\\SRS SR780 Data\\"
digitalHP_DataHome = "C:\\Users\\Mark\\Documents\\My Data Analysis\\Data 16_06_27\\Digital Servo Data\\HP 4395A Data\\"
digitalSRS_DataHome = "C:\\Users\\Mark\\Documents\\My Data Analysis\\Data 16_06_27\\Digital Servo Data\\SRS SR780 Data\\"
# %matplotlib inline

# %%
{"# ## Notes about HP Configuration"
 "dBm per hertz returned"
 "  Analog Data ###########"
    "# NOTES: "
    "# HP Spectrum Analyzer Data: "
    "# Spectrum Analyzer Bandwidth = 50 Hz"
    "# Spectra Readings Units: dBm/Hz"
    "# Ranges: 0-500 kHz, 0-100KHz, 0-6kHz"
    "# Other: 10dB Attenuator on input. No in-machine attenuation."
 ""}

{""
 "# ## Notes about SRS Configuration"
 "# 500 Averages"
 "# dBm (not per hertz!) numbers returned (this is different from yesterday! Yesterday was Vrms, I "
 "changed it for better consistency between this data and the HP Data."
 "" 
 ""}
# Out:
# {'# ## Notes about SRS Configuration# 500 Averages# dBm (not per hertz!) numbers returned (this is different from yesterday! Yesterday was Vrms, I changed it for better consistency between this data and the HP Data.'}

# %%
# analog data only
# High frequencies = 50 Hz BW
# Medium = 30 Hz BW
# Low = 5 Hz BW

hpAnalogNoLightHigh = SA.import_HP4395A_Data(analogHP_DataHome + "7mW Analog No Light High Frequency.TXT") 
hpAnalogNoLightMed = SA.import_HP4395A_Data(analogHP_DataHome + "7mW Analog No Light Medium Frequency.TXT")
hpAnalogNoLightLow = SA.import_HP4395A_Data(analogHP_DataHome + "7mW Analog No Light low Frequency.TXT")

hpAnalogOffHigh = SA.import_HP4395A_Data(analogHP_DataHome + "7mW Analog Servo Off High Frequency.TXT")
hpAnalogOffMed = SA.import_HP4395A_Data(analogHP_DataHome + "7mW Analog Servo Off Medium Frequency.TXT")
hpAnalogOffLow = SA.import_HP4395A_Data(analogHP_DataHome + "7mW Analog Servo Off Low Frequency.TXT")

hpAnalogOnHigh = SA.import_HP4395A_Data(analogHP_DataHome + "7mW Analog Servo On High Frequency.TXT")
hpAnalogOnMed = SA.import_HP4395A_Data(analogHP_DataHome + "7mW Analog Servo On Medium Frequency.TXT")
hpAnalogOnLow = SA.import_HP4395A_Data(analogHP_DataHome + "7mW Analog Servo On Low Frequency.TXT")

srsAnalogNoLightLow = SA.import_SRSSR780_Data(analogSRS_DataHome + "7mW Analog No Light Low Frequency.TXT")
srsAnalogNoLightMed = SA.import_SRSSR780_Data(analogSRS_DataHome + "7mW Analog No Light Medium Frequency.TXT")

srsAnalogOnLow = SA.import_SRSSR780_Data(analogSRS_DataHome + "7mW Analog Servo On Low Frequency.TXT")
srsAnalogOnMed = SA.import_SRSSR780_Data(analogSRS_DataHome + "7mW Analog Servo On Medium Frequency.TXT")

srsAnalogOffLow = SA.import_SRSSR780_Data(analogSRS_DataHome + "7mW Analog Servo Off Low Frequency.TXT")
srsAnalogOffMed = SA.import_SRSSR780_Data(analogSRS_DataHome + "7mW Analog Servo Off Medium Frequency.TXT")

# %%
myFig = plt.figure(1, facecolor="white", figsize=(20, 10))
plt.plot(hpAnalogNoLightHigh["Frequency"], hpAnalogNoLightHigh["Data Trace"], 
         label="Analog Settings No Light")
plt.plot(hpAnalogOffHigh["Frequency"], hpAnalogOffHigh["Data Trace"], 
         label="Analog Settings Servo Off")
plt.plot(hpAnalogOnHigh["Frequency"], hpAnalogOnHigh["Data Trace"], 
         label="Analog Settings Servo On")
plt.title("Analog Servo Data High Frequencies")
plt.xlabel("Frequency")
plt.ylabel("dBm/Hertz")
plt.xscale("log")
plt.legend()
plt.grid(which="both")
#plt.savefig
plt.show()
# ######################
myFig = plt.figure(3, facecolor="white", figsize=(20, 10))
plt.plot(hpAnalogNoLightLow["Frequency"], hpAnalogNoLightLow["Data Trace"], 
         label="Analog Settings No Light")
plt.plot(hpAnalogOffLow["Frequency"], hpAnalogOffLow["Data Trace"], 
         label="Analog Settings Servo Off")
plt.plot(hpAnalogOnLow["Frequency"], hpAnalogOnLow["Data Trace"], 
         label="Analog Settings Servo On")
plt.title("Analog Servo Data Low Frequencies")
plt.xlabel("Frequency")
plt.ylabel("dBm/Hertz")
plt.legend()
plt.xscale("log")
plt.grid(which="both")
#plt.savefig
plt.show()
# ######################
myFig = plt.figure(2, facecolor="white", figsize=(20, 10))
plt.plot(hpAnalogNoLightMed["Frequency"], hpAnalogNoLightMed["Data Trace"], 
         label="Analog Settings No Light")
plt.plot(hpAnalogOffMed["Frequency"], hpAnalogOffMed["Data Trace"], 
         label="Analog Settings Servo Off")
plt.plot(hpAnalogOnMed["Frequency"], hpAnalogOnMed["Data Trace"], 
         label="Analog Settings Servo On")
plt.title("Analog Servo Data Medium Frequencies")
plt.xlabel("Frequency")
plt.ylabel("dBm/Hertz")
plt.legend()
plt.xscale("log")
plt.grid(which="both")
#plt.savefig
plt.show()

# %%
#  14000 Hz
#  -4dBm
# infinite gain limit
# ### low
# 10000
# 0.0 dB

hpDigitalBadPowerLocation = SA.import_HP4395A_Data(digitalHP_DataHome 
                                             + "Initial Digital Servo Bad Power High Frequencies.TXT") 
hpDigitalGoodPowerLocation = SA.import_HP4395A_Data(digitalHP_DataHome 
                                             + "Initial Digital Servo Good Power High Frequencies.TXT")
hpDigitalServoOff = SA.import_HP4395A_Data(digitalHP_DataHome 
                                             + "Initial Digital Servo Off.TXT")

# %%
myFig = plt.figure(3, facecolor="white", figsize=(20, 10))
#plt.plot(hpDigitalBadPowerLocation["Frequency"], hpDigitalBadPowerLocation["Data Trace"], 
#         label="Digital Settings Servo Bad Power")
plt.plot(hpDigitalGoodPowerLocation["Frequency"], hpDigitalGoodPowerLocation["Data Trace"], 
         label="Digital Settings Servo Good Power")
plt.plot(hpDigitalServoOff["Frequency"], hpDigitalServoOff["Data Trace"], 
         label="Digital Settings Servo Off")
plt.plot(hpAnalogOnHigh["Frequency"], hpAnalogOnHigh["Data Trace"], 
         label="Analog Settings Servo On")
plt.plot(hpAnalogOffHigh["Frequency"], hpAnalogOffHigh["Data Trace"], 
         label="Analog Settings Servo On")

plt.title("Servo Data High Frequencies")
plt.xlabel("Frequency")
plt.ylabel("dBm/Hertz")
plt.legend()
plt.xscale("log")
plt.grid(which="both")
plt.axis([1e4, 5e5,-130,-90])
plt.savefig("Digital Vs. Analog Initial Comparison.png")
plt.show()

# %%
# Tuning the peak around 250 kHz, changing PI Corner and gain without the low pass filter

hpDigitalNoLowPass_m4dBm_14kHz = SA.import_HP4395A_Data(digitalHP_DataHome 
                                                        + "Digital Servo On -4dBm 14kHz.TXT")
hpDigitalNoLowPass_m5dBm_14kHz = SA.import_HP4395A_Data(digitalHP_DataHome 
                                                        + "Digital Servo On -5dBm 14kHz.TXT")
hpDigitalNoLowPass_m6dBm_14kHz = SA.import_HP4395A_Data(digitalHP_DataHome 
                                                        + "Digital Servo On -6dBm 14kHz.TXT")
hpDigitalNoLowPass_m7dBm_14kHz = SA.import_HP4395A_Data(digitalHP_DataHome 
                                                        + "Digital Servo On -7dBm 14kHz.TXT")
hpDigitalNoLowPass_m8dBm_14kHz = SA.import_HP4395A_Data(digitalHP_DataHome 
                                                        + "Digital Servo On -8dBm 14kHz.TXT")
hpDigitalNoLowPass_m4dBm_8kHz = SA.import_HP4395A_Data(digitalHP_DataHome 
                                                        + "Digital Servo On -4dBm 8kHz.TXT")
hpDigitalNoLowPass_m4dBm_30kHz = SA.import_HP4395A_Data(digitalHP_DataHome 
                                                        + "Digital Servo On -4dBm 30kHz.TXT")
hpDigitalNoLowPass_m8dBm_8kHz = SA.import_HP4395A_Data(digitalHP_DataHome 
                                                        + "Digital Servo On -8dBm 8kHz.TXT")
hpDigitalNoLowPass_m8dBm_30kHz = SA.import_HP4395A_Data(digitalHP_DataHome 
                                                        + "Digital Servo On -4dBm 30kHz.TXT")

# %%
myFig = plt.figure(1, facecolor="white", figsize=(20, 10))
#plt.plot(hpDigitalBadPowerLocation["Frequency"], hpDigitalBadPowerLocation["Data Trace"], 
#         label="Digital Settings Servo Bad Power")
plt.plot(hpDigitalNoLowPass_m4dBm_14kHz["Frequency"], hpDigitalNoLowPass_m4dBm_14kHz["Data Trace"], 
         label="-4dBm")
plt.plot(hpDigitalNoLowPass_m5dBm_14kHz["Frequency"], hpDigitalNoLowPass_m5dBm_14kHz["Data Trace"], 
         label="-5dBm")
plt.plot(hpDigitalNoLowPass_m6dBm_14kHz["Frequency"], hpDigitalNoLowPass_m6dBm_14kHz["Data Trace"], 
         label="-6dBm")
plt.plot(hpDigitalNoLowPass_m7dBm_14kHz["Frequency"], hpDigitalNoLowPass_m7dBm_14kHz["Data Trace"], 
         label="-7dBm")
plt.plot(hpDigitalNoLowPass_m8dBm_14kHz["Frequency"], hpDigitalNoLowPass_m8dBm_14kHz["Data Trace"], 
         label="-8dBm")

plt.title("Servo Data No Low Pass Varying PI Gain")
plt.xlabel("Frequency")
plt.ylabel("dBm/Hertz")
plt.legend()
plt.xscale("log")
plt.grid(which="both")
plt.axis([1e4, 5e5,-130,-60])
plt.savefig("Controlling Resonance With Gain.png")
plt.show()
# ###################
myFig = plt.figure(2, facecolor="white", figsize=(20, 10))
#plt.plot(hpDigitalBadPowerLocation["Frequency"], hpDigitalBadPowerLocation["Data Trace"], 
#         label="Digital Settings Servo Bad Power")
plt.plot(hpDigitalNoLowPass_m4dBm_8kHz["Frequency"], hpDigitalNoLowPass_m4dBm_8kHz["Data Trace"], 
         label="-4dBm, 8kHz")
plt.plot(hpDigitalNoLowPass_m4dBm_14kHz["Frequency"], hpDigitalNoLowPass_m4dBm_14kHz["Data Trace"], 
         label="-4dBm, 14kHz")
plt.plot(hpDigitalNoLowPass_m4dBm_30kHz["Frequency"], hpDigitalNoLowPass_m4dBm_30kHz["Data Trace"], 
         label="-4dBm, 30kHz")
plt.plot(hpDigitalNoLowPass_m8dBm_8kHz["Frequency"], hpDigitalNoLowPass_m8dBm_8kHz["Data Trace"], 
         label="-8dBm, 8kHz")
plt.plot(hpDigitalNoLowPass_m8dBm_14kHz["Frequency"], hpDigitalNoLowPass_m8dBm_14kHz["Data Trace"], 
         label="-8dBm, 14kHz")
plt.plot(hpDigitalNoLowPass_m8dBm_30kHz["Frequency"], hpDigitalNoLowPass_m8dBm_30kHz["Data Trace"], 
         label="-8dBm, 30kHz")

plt.title("Servo Data No Low Pass Varying PI Corner")
plt.xlabel("Frequency")
plt.ylabel("dBm/Hertz")
plt.legend()
plt.xscale("log")
plt.grid(which="both")
plt.axis([1e4, 5e5,-130,-60])
plt.savefig("Controlling Resonance With Corner.png")
plt.show()

# %%
# Getting a quick look at low frequency data for 7mW

srsDigitalOffLow = SA.import_SRSSR780_Data(digitalSRS_DataHome 
                                                        + "Servo Off Low Frequencies.TXT")
srsDigitalOffLow2 = SA.import_SRSSR780_Data(digitalSRS_DataHome 
                                                        + "Servo Off Low Frequencies (2).TXT")
srsDigitalOffLow3 = SA.import_SRSSR780_Data(digitalSRS_DataHome 
                                                        + "Servo Off Low Frequencies (3).TXT")
srsDigitalOnLow = SA.import_SRSSR780_Data(digitalSRS_DataHome 
                                                        + "Servo On Low Frequencies.TXT")
srsDigitalOnLow2 = SA.import_SRSSR780_Data(digitalSRS_DataHome 
                                                        + "Servo On Low Frequencies (2).TXT")
srsDigitalOffMedium = SA.import_SRSSR780_Data(digitalSRS_DataHome 
                                                        + "Servo Off Medium Frequencies.TXT")

# %%
# ###################
myFig = plt.figure(1, facecolor="white", figsize=(20, 10))
plt.plot(srsDigitalOffLow[0], srsDigitalOffLow[1], 
         label="Servo Off")
plt.plot(srsDigitalOffLow2[0], srsDigitalOffLow2[1], 
         label="Servo Off (2)")
plt.plot(srsDigitalOffLow3[0], srsDigitalOffLow3[1], 
         label="Servo Off (3)")
plt.plot(srsDigitalOnLow[0], srsDigitalOnLow[1], 
         label="Servo On")
plt.plot(srsDigitalOnLow2[0], srsDigitalOnLow2[1], 
         label="Servo On (2)")

plt.plot(srsAnalogOffLow[0], srsAnalogOffLow[1], label="analog off (taken at same time as digital")
plt.plot(srsAnalogOnLow[0], srsAnalogOnLow[1], label="analog on (older)")

plt.title("Quick look low servo data")
plt.xlabel("Frequency")
plt.ylabel("dBm/Hertz")
plt.legend()
plt.xscale("log")
plt.grid(which="both")
#plt.axis([1e4, 5e5,-130,-60])
plt.savefig("Digital Servo Off Fluctuating.png")
plt.show()

# %%
srsDigitalLowPass_10MHz = SA.import_SRSSR780_Data(digitalSRS_DataHome 
                                                        + "7mW Digital Servo 10MHz Corner.TXT")
srsDigitalLowPass_8MHz = SA.import_SRSSR780_Data(digitalSRS_DataHome 
                                                        + "7mW Digital Servo 8MHz Corner.TXT")
srsDigitalLowPass_6MHz = SA.import_SRSSR780_Data(digitalSRS_DataHome 
                                                        + "7mW Digital Servo 6MHz Corner.TXT")
srsDigitalLowPass_4MHz = SA.import_SRSSR780_Data(digitalSRS_DataHome 
                                                        + "7mW Digital Servo 4MHz Corner.TXT")
srsDigitalLowPass_2MHz = SA.import_SRSSR780_Data(digitalSRS_DataHome 
                                                        + "7mW Digital Servo 2MHz Corner.TXT")
srsTALowerPower = SA.import_SRSSR780_Data(digitalSRS_DataHome 
                                                        + "TA Lower Power.TXT")
hpLessNoise = SA.import_HP4395A_Data((digitalHP_DataHome + "Medium Frequency Less Noise.TXT"))

# %%
# ###################
myFig = plt.figure(1, facecolor="white", figsize=(20, 10))
plt.plot(srsDigitalLowPass_10MHz[0], srsDigitalLowPass_10MHz[1], 
         label="10MHz")
plt.plot(srsDigitalLowPass_8MHz[0], srsDigitalLowPass_8MHz[1], 
         label="8MHz")
plt.plot(srsDigitalLowPass_6MHz[0], srsDigitalLowPass_6MHz[1], 
         label="6MHz")
plt.plot(srsDigitalLowPass_4MHz[0], srsDigitalLowPass_4MHz[1], 
         label="4MHz")
plt.plot(srsDigitalLowPass_2MHz[0], srsDigitalLowPass_2MHz[1], 
         label="2MHz")
plt.plot(srsTALowerPower[0], srsTALowerPower[1], label="TA @ Lower Current")

plt.plot(srsDigitalOffMedium[0], srsDigitalOffMedium[1], label="Digital off")
plt.plot(srsAnalogOffMed[0], srsAnalogOffMed[1], label="analog off (taken at same time as digital")
plt.plot(srsAnalogOnMed[0], srsAnalogOnMed[1], label="analog on (older)")

plt.title("Quick look low servo data")
plt.xlabel("Frequency")
plt.ylabel("dBm/Hertz")
plt.legend()
plt.xscale("log")
plt.grid(which="both")
plt.axis([1e2, 1e5, -90, -40])
plt.savefig("Digital SRS Medium Range Lots of Noise.png")
plt.show()
#
myFig = plt.figure(2, facecolor="white", figsize=(20, 10))
plt.plot(hpLessNoise["Frequency"], hpLessNoise["Data Trace"], label="HP Data same range less noise")
plt.title("")
plt.xlabel("Frequency")
plt.ylabel("dBm/Hertz")
plt.legend()
plt.xscale("log")
plt.grid(which="both")
plt.axis([1e2, 1e5, -120, -70])
plt.savefig("Digital HP Medium Range no noise.png")
plt.show()
