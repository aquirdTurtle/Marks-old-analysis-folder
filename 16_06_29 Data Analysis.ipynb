# %%
import Spectrum_Analysis as SA
import matplotlib.pyplot as plt
import numpy as np
analogHP_DataHome = "C:\\Users\\Mark\\Documents\\My Data Analysis\\Data 16_06_29\\Analog Servo Data\\HP 4395A Data\\"
analogSRS_DataHome = "C:\\Users\\Mark\\Documents\\My Data Analysis\\Data 16_06_29\\Analog Servo Data\\SRS SR780 Data\\"
digitalHP_DataHome = "C:\\Users\\Mark\\Documents\\My Data Analysis\\Data 16_06_29\\Digital Servo Data\\HP 4395A Data\\"
digitalSRS_DataHome = "C:\\Users\\Mark\\Documents\\My Data Analysis\\Data 16_06_29\\Digital Servo Data\\SRS SR780 Data\\"
# %matplotlib inline

# %%
old = SA.import_SRSSR780_Data(digitalSRS_DataHome + "Old Agilent.TXT")
new = SA.import_SRSSR780_Data(digitalSRS_DataHome + "New Agilent.TXT")

# %%
plt.plot(old[0], old[1], label="old")
plt.plot(new[0], new[1], label="new")
plt.xscale("log")

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
myFig = plt.figure(1, facecolor="white", figsize=(20, 10))

x = np.linspace(-3, 7, 100)
y = (np.sin(1-x/2))**2/(2-x)**2 
plt.plot(x,y)
plt.savefig("C:/Users/Mark/Documents/My Data Analysis/test.png")

# %%
2**(5/4)/(1.5*10**5)

# %%
hello

# %%
# MARKDOWN
